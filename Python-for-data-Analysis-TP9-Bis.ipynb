# %% [markdown]
# # TP9 Python for Data Analysis
#
#
#
# ## pip & conda :
#
#
#
# pip and condas are two python package manager.
#
# pip does not allow multiple environments, it does not support multiple versions of same library installed
#
# pip does not know anything about python versions - python 2, python 3? Python 3.5 or 3.6? It can’t help with that.
#
# **You should be aware of all the pip and python versions you have on your machine, and know their locations on your drive.**

# %%
# pour savoir ou un package est installé :
# to know where a package is installed : 
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.0.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages
# Requires: python-dateutil, numpy, pytz
# Required-by: geopandas, statsmodels, seaborn, ppscore, catboost, autokeras

# %%
# ATTENTION ! si vous lancez pip dans votre powershell, vous aurez peut être un autre résultat.
# C'est parceque pip peut être installé aussi dans un environnement conda, ce qui est le cas chez moi. Mon notebook jupyter est lancé par visualstudiocode dans un environnement conda. Le pip qui est alors dans le PATH, installe ses packages dans les dossiers conda, ce qui peut être source de conflits..

# %%
# pour lister les packages installés
# to list installed packages
# !pip list -v
# Out:
# Package                            Version                Location                                               Installer
# ---------------------------------- ---------------------- ------------------------------------------------------ ---------
# absl-py                            0.11.0                 /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages pip
# alabaster                          0.7.12                 /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages conda
# anaconda-client                    1.7.2                  /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages conda
# anaconda-navigator                 1.9.12                 /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages
# anaconda-project                   0.8.3                  /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages conda
# applaunchservices                  0.2.1                  /Users/J-Luc/opt/anaconda3/lib/python3.8/site-packages conda
# ...

# %% [markdown]
# Conda can manage multiple environements, with multiple python and packages versions.

# %%
# Pour lister les environnement disponibles :
# to list available environments : 
# conda env list

# Pour créer un environnement:
# To create an environment: 
# conda create -n TP9 

# Pour activer un environnement :
# To acticate an environment : 
# conda activate TP9

# une fois un environnement activé, toutes les conda install que vous ferez seront liées a cet environnement
# once an environment is activated, all "conda install" will go into this environement.
# Out:
#   File "<ipython-input-3-a65f6570c86d>", line 3
#     conda env list
#           ^
# SyntaxError: invalid syntax

# %%
# Sometimes you are using pip within an conda environement. 
# The problem is that you can have many pip versions installed.
# on linux and mac you can type "which -a pip" to find your different pip version
# If you want to use pip within conda, I suggest you always 'conda install pip'
# and then to locate your anaconda directory, and find the actual venv folder
# and to launch pip install from this folder.

# %% [markdown]
# https://modelpredict.com/how-not-to-break-your-python-environment-again/
#
# https://stackoverflow.com/questions/41060382/using-pip-to-install-packages-to-anaconda-environment
#
# ( pour ajouter python au path windows : https://geek-university.com/python/add-python-to-the-windows-path/ )

# %% [markdown]
# ## HARDWARE TALKS : CPU / GPU / TPU , Jetson nano
#
#
#
# CPU can do complicated things with a small concurrency (parralelism) (48 cores for a big server CPU)
# GPU can do simple things, with a very high concurrency( hundreds of cores on a single chip)
# GPUs can be incredibly fast when they're given very simple things to do in parallel, but they're incredibly slow when complex instructions are involved, especially things like switching statements (if-then-else type things), where CPUs fare much better.
#
# Specifically, GPU's do two things really well:
#
# Floating-point operations (operations with decimal numbers instead of just integers), such as physics and graphics stuff, linear algebra.
#
# Operations that involve running the exact same code on a huge number of different data points at once. For example, calculating the light/shadow/color for all the millions of different pixels on the screen when rendering something. This is also known as "parallelism".
#
#
# IF YOU HAVE A GPU : try to use Tensorflow with it, and compare execution time with the same code runing on CPU
#
# ### Using your GPU with tensorflow :
# https://stackoverflow.com/questions/51306862/how-do-i-use-tensorflow-gpu
#
# https://www.tensorflow.org/guide/gpu
#
# https://www.tensorflow.org/install/gpu?hl=fr
#
#
#
# KAGGLE / google colab TPU : free firepower !
# it's free ! make use of it.
#
# ### Using google colab TPU :
# https://colab.research.google.com/notebooks/tpu.ipynb
#
# ### Using google colab GPU
#
# Menu Runtime | Change runtime type | GPU
# and that's it ! it should work with tensorflow.
#
# ### to go further :
#
# https://medium.com/dataseries/cpu-gpu-and-tpu-machine-learning-5033e25b8a0f
#
#
# https://www.quora.com/What-kind-of-math-is-a-graphics-card-better-at-than-a-CPU
#
# https://www.omnisci.com/technical-glossary/cpu-vs-gpu#:~:text=The%20main%20difference%20between%20CPU,resolution%20images%20and%20video%20concurrently.

# %% [markdown]
# ### Nvidia Jetson mini computers :
#
# https://thenextweb.com/plugged/2019/03/19/nvidias-just-released-a-99-pocket-sized-computer-for-ai-devs/
#
# https://developer.nvidia.com/embedded-computing
#
# see here what you can do with it :
# https://developer.nvidia.com/embedded/community/jetson-projects

# %% [markdown]
# ## COMPARE EXECUTION TIME.
#
# Being able to speed up learning or response time of a model is part of your job !
#
# Here is a way to measure execution time :

# %%
import time
start_time = time.time()

for i in range(0,10000000):
    a=i*i

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1.6617257595062256 seconds ---

# %% [markdown]
# Here is another way, that will work ONLY in a jupyter notebook :

# %%
# %%time
for i in range(0,10000000):
    a=i*i
# Out:
# CPU times: user 1.58 s, sys: 24.5 ms, total: 1.61 s
# Wall time: 1.74 s

# %% [markdown]
# # CNN
#
#
# **Deep Learning** is the branch of Machine Learning based on Deep Neural Networks (DNNs), meaning neural networks with at the very least 3 or 4 layers (including the input and output layers).
#
#
#
#
# **Convolutional Neural Networks (CNNs)** are one of the most popular neural network architectures. They are extremely successful at image processing, but also for many other tasks (such as speech recognition, natural language processing, and more). The state of the art CNNs are pretty deep (dozens of layers at least), so they are part of Deep Learning. But you can build a shallow CNN for a simple task, in which case it's not (really) Deep Learning.
#
# They are a type of neural netowrk inspired by visual cortex of animals, with a succession of perception layers
#
#
# ### 1) a Historical and Theorical introduction
#
# https://blog.xrds.acm.org/2016/06/convolutional-neural-networks-cnns-illustrated-explanation/
#
# "The modern Convolutional Neural Networks owe their inception to a well-known 1998 research paper[4] by Yann LeCun and Léon Bottou. In this highly instructional and detailed paper, the authors propose a neural architecture called LeNet 5 used for recognizing hand-written digits and words that established a new state of the art2 classification accuracy of 99.2% on the MNIST dataset[5].
#
# According to the author’s accounts, CNNs are biologically-inspired models. The research investigations carried out by D. H. Hubel and T. N. Wiesel in their paper[6] proposed an explanation for the way in which mammals visually perceive the world around them using a layered architecture of neurons in the brain, and this in turn inspired engineers to attempt to develop similar pattern recognition mechanisms in computer vision.
# The most popular application for CNNs in the recent times has been Image Analysis, but many researchers have also found other interesting and exciting ways to use them: from winning Go matches against human players([7], a related video [8]) to an innovative application in discovering new drugs by training over large quantities of molecular structure data of organic compounds[9]."
#
# CNN have evolved since their inception.
# You will find here the ImageNet Challenge History. The contest is now hosted by Kaggle
#
# https://medium.com/analytics-vidhya/cnns-architectures-lenet-alexnet-vgg-googlenet-resnet-and-more-666091488df5
#
# https://www.kaggle.com/getting-started/149448
#
#
# ### 2) CNN LESSONS
#
# Kaggle:
# https://www.kaggle.com/learn/computer-vision
#
# Google:
# https://www.tensorflow.org/tutorials/images/cnn
#
#
#
# ### 3) HANDS ON : A CNN TO CLASSIFY THE MNIST FASHION DATASET
#
#
# https://github.com/zalandoresearch/fashion-mnist
#
# "Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. We intend Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits."
#
# download the dataset : https://www.kaggle.com/zalando-research/fashionmnist
#
#
# The Fashion-MNIST became the de facto standard for benchmarking Image Recognition neural network. You will find online many tutorials using it. I propose here 3 of them. Give a short look to all of them to choose the one you like best. If something is not clear, maybe it will be better explained in one of the other.
#
#
# https://www.kaggle.com/gpreda/cnn-with-tensorflow-keras-for-fashion-mnist
#
# https://www.kaggle.com/pavansanagapati/a-simple-cnn-model-beginner-guide
#
# https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-fashion-mnist-clothing-classification/
#
# If you have a GPU, try to do these tutorial with your GPU and compare execution times.

# %% [markdown]
# One of your classmate wrote a very pedagogic article to better understand what's happening Backstage during a CNN :
# https://towardsdatascience.com/conv2d-to-finally-understand-what-happens-in-the-forward-pass-1bbaafb0b148

# %% [markdown]
# # PRACTICAL WORK
#
# -> Implement a CNN on fashion MNIST dataset running on your computer's CPU
#
# -> Implement a CNN on fashion MNIST dataset on google colab
#
# -> Compare training duration time using your computer's CPU, and google colab GPU and TPU ( 3 time measurements )
#
# -> If you have a local GPU, include it in the benchmark.
#
# -> Can you find the number of cores of your CPU ? ( Tensorflow automatically runs the computations on as many cores as are available on a single machine. )
#
# -> Can you find the number of cores of the GPU used in your google colab notebook ?

# %% [markdown]
# # Reinforcement Learning
#
#
# An algorithm must reach a goal. A reward is given on each move. Its goal is to maximize the total reward.
# RL is not supervised. It can find his way alone.
#
#
#
# Good introduction on youtube :  https://youtu.be/cO5g5qLrLSo
#
# Presentation  :  https://www.dropbox.com/s/7033q1eg9plg3u9/esilv_reinforcement_learning_basique.pptx?dl=0
#
# Romain Jouin Notebook : https://www.dropbox.com/s/znmjp65lgscb293/ESILV_TP_7_reinforcement_learning.ipynb?dl=0
#
#
# Deep RL in images : https://www.youtube.com/watch?v=j8rSWvcO-s4&ab_channel=masato2ka
#
#
#
#
# bon travail à tous.
